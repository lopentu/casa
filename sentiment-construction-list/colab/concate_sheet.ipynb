# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/Shareddrives/LOPE/產學合作/中華電信/2020-2021/指向情緒案/sentiment-construction-list')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials

# setup
gc = gspread.authorize(GoogleCredentials.get_application_default())

# read data and put it in a dataframe
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/13mqAddL8goWjqOTvOhPD9cWl7LfDeUm-qgcpoAMzq_A/edit?usp=sharing')

import pandas as pd
sheets1 = gsheets.worksheet('andrea').get_all_values()
df1 = pd.DataFrame(sheets1[1:], columns=sheets1[0])
sheets2 = gsheets.worksheet('amy').get_all_values()
df2 = pd.DataFrame(sheets2[1:], columns=sheets2[0])
sheets3 = gsheets.worksheet('evelyn').get_all_values()
df3 = pd.DataFrame(sheets3[1:], columns=sheets3[0])

# %%
df3 = df[["attribute", "candidate", "polarity", "relatedness"]]
df3
# Out:
#       attribute candidate polarity relatedness
# 0        [通訊]網速        穩定        5           5
# 1      [資費]方案活動        不錯        4           2
# 2        [其他]固網        穩定        5           5
# 3    [加值]vowifi        好用        5           4
# 4    [加值]vowifi      也夠用了        4           4
# ..          ...       ...      ...         ...
# 105      [通訊]涵蓋        很順        5           5
# 106      [通訊]涵蓋       很不錯        4           3
# 107      [通訊]涵蓋       這麼差        1           3
# 108      [通訊]涵蓋        ok        4           3
# 109      [通訊]涵蓋        較差        2           3
#
# [110 rows x 4 columns]

# %%
frames = [df1, df2, df3]
df_all = pd.concat(frames)
df_all
# Out:
#       attribute candidate polarity relatedness
# 0        [通訊]網速        穩定        5           5
# 1      [資費]方案活動        不錯        4           2
# 2        [其他]固網        穩定        5           5
# 3    [加值]vowifi        好用        5           4
# 4    [加值]vowifi      也夠用了        4           4
# ..          ...       ...      ...         ...
# 105      [通訊]涵蓋        很順        5           5
# 106      [通訊]涵蓋       很不錯        4           3
# 107      [通訊]涵蓋       這麼差        1           3
# 108      [通訊]涵蓋        ok        4           3
# 109      [通訊]涵蓋        較差        2           3
#
# [304 rows x 4 columns]

# %%
df_all.to_csv('onto_annot_all.csv', index=False)
