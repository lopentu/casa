# %%
from google.colab import drive
drive.mount('/content/drive')
import csv
import re
import random
import tqdm.notebook as tq
import pandas as pd
import json
import pprint
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. 讀入語料與構式辭典

# %%
file_path = '/content/drive/Shareddrives/LOPE/產學合作/中華電信/2020-2021/指向情緒案/data/threads/cht-2020-merged.txt'

with open(file_path, 'r', encoding = 'utf-8') as f:
  comments = [ line.strip() for line in f ] # comments 中的每一個 element 是一則評論

# %%
construction_path = '/content/drive/Shareddrives/LOPE/產學合作/中華電信/2020-2021/指向情緒案/sentiment-construction-list/data/constructions_0406.csv'

with open(construction_path) as f:
    constructions = [ row.strip() for row in f ]

# %% [markdown]
# ## 2. 從每則評論中找出符合的構式例子

# %%
n = 5  # sample size
random.seed(10)

matched = {}
matched_con = {}
for k in tq.tqdm(constructions):
  pat = re.compile(k)
  if k not in matched: matched[k] = []
  
  # Get all cnstr from all comments
  candidates = set()
  for cmt in comments:
    for c in pat.finditer(cmt): candidates.add(c[0])
  
  # Count all cnstr
  matched_con[k] = len(candidates)

  # Sample
  if len(candidates) > n:
    for c in random.sample(candidates, n): matched[k].append(c)
  else:
    for c in candidates: matched[k].append(c)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=39.0), HTML(value='')))

# %%
constructions[1]
# Out:
# '純噓\\w+\\b'

# %%
pprint.pprint(matched)
# Out:
# {'(對\\w+)?一點(都|也)不\\w+\\b': ['一點都不貴',
#                              '一點都不考慮',
#                              '一點都不深奧深奧的地方在價錢',
#                              '一點都不意外',
#                              '一點都不值得'],
#  '(很|也)夠\\w+了\\b': ['也夠買一隻平價機了', '也夠優了', '也夠鄉下了', '很夠了應該也不會升就是了', '也夠打94分鐘了'],
#  '(真的)?有夠\\w+的?\\b': ['有夠正',
#                       '有夠猛的',
#                       '有夠沒誠意',
#                       '有夠差一場正常ping一場爆ping要怎麼玩',
#                       '真的有夠低能'],
#  '(置|拉)板凳等\\w+\\b': ['置板凳等後續', '拉板凳等中華'],
#  '\\b\\w+(到|的|得)離譜': ['上傳更是低得離譜',
#                       '寫的資料錯的離譜',
#                       '開台就是貴的離譜',
#                       '邏輯到離譜',
#                       '小弟住在一中商圈方案為488吃到飽之前都是正常的但最近幾天網速慢到離譜'],
#  '\\b\\w+(掰|bye)了': ['我想就掰了',
#                      '出了市區偏遠地區如海邊山上就掰掰了',
#                      '就要跟你說掰掰了',
#                      '所以要和便宜的吃到飽說掰了',
#                      '門號跟你說byebye了'],
#  '\\b\\w+(的|得)要死': ['上網恨慢得要死', '幹的要死', '我是在二樓網路真的爛的要死', '網速慢的要死', '態度還差的要死'],
#  '\\b\\w+到\\w*炸了?': ['幹來台南生活到哪都容易沒訊號稍微進一個建築物網路就直接炸',
#                      '真的是爛到一個炸',
#                      '慢到炸',
#                      '中華喔一堆人晚上拿中華吃到飽當固網分享給筆電打lol看影片周邊基地台只要有多一點這種人妳的網路在這個時段就炸',
#                      'mk2的使用感受真的是垃圾到炸'],
#  '\\b\\w+屌打\\w+\\b': ['那我想被原本戲謔但第二屆認真搞的走鐘獎屌打也是應該的看到其中一則留言寫得很好',
#                       '中華屌打台哥',
#                       '哇靠真的屌打中華耶',
#                       '嗯畫質屌打狗屎的狂野飆車',
#                       '是否能屌打全世界國家'],
#  '\\b\\w+廢到笑': ['5g看到新聞報導中華初步兩千座基地台就無言了廢到笑',
#                 '企客688真的是廢到笑',
#                 '獲利王真的廢到笑',
#                 '當初4g最初的費率也是一些流量廢到笑',
#                 '我家訊號廢到笑'],
#  '\\b\\w+心酸的?\\w*\\b': ['好心酸',
#                         '所以是排心酸的嗎',
#                         '但要查資料還是木抖點名的時候真的很幹我吃到飽的費用是繳心酸的嗎嗚嗚嗚嗚希望趕快約到期',
#                         '老索粉的心酸歷程',
#                         '1399是付心酸的'],
#  '\\b\\w+敲盤子\\w*\\b': ['蘋果又出來敲盤子',
#                        '不然台灣人還在被三大敲盤子',
#                        '遠傳台哥是敲盤子喔',
#                        '各家都拿高資費來敲盤子顆顆',
#                        '根本敲盤子'],
#  '\\b\\w+是在哈囉': ['單是在哈囉', '自己說法前後矛盾是在哈囉', '網路是在哈囉', '這是在哈囉', '你給我更新軟體是在哈囉'],
#  '\\b\\w+根本\\w{2}\\b': ['店家根本違約',
#                         '前面的人網購操作很慢根本悲劇',
#                         'wifi路由器wan燈根本沒亮',
#                         '用不完的還可以轉到名下門號繼續根本方便',
#                         '資費這樣比根本無理'],
#  '\\b\\w+秀下限\\w+\\b': ['自己搞不到管道別秀下限了',
#                        '井蛙不要秀下限好嗎',
#                        '先搞懂小七業務再來秀下限喔',
#                        '賣勾來這秀下限了',
#                        'bz真的是來秀下限的'],
#  '\\b\\w+給力\\b': ['呱張給力',
#                   '我看前面兩篇都說399給力',
#                   '88結最給力',
#                   '又覺得中華網路還是給力',
#                   'iphone電池不給力'],
#  '\\b\\w+能\\w\\s?，?\\w+都能\\w了\\b': ['屁話能信史都能吃了', '店員的話能信，連屎都能吃了'],
#  '\\b\\w+被當盤子\\w*\\b': ['是被當盤子耍吧',
#                         '繳4g吃到飽被當盤子',
#                         '只是被當盤子而已',
#                         '那你這四年會無數次被當盤子',
#                         '到底是本人覺得被當盤子賺'],
#  '\\b\\w+雞肋': ['根本雞肋', '上傳是雞肋', '拿雞肋', '所以優惠在那個網內簡訊就是雞肋', '之前一直覺得像雞肋'],
#  '\\b\\w到爆\\w?\\b': ['卡到爆炸', '幹到爆', '香到爆', '爽到爆', '爛到爆炸'],
#  '\\b三不五時就\\w+\\b': ['三不五時就卡住',
#                      '三不五時就有要你續約較高資費但可降速吃到飽的廣告',
#                      '三不五時就在發',
#                      '三不五時就看到授權商在半價換電池之類的',
#                      '三不五時就有人說是台星的金援'],
#  '\\w+就贏了': ['這樣他就贏了',
#              '我就贏了',
#              '最高只有35m的話4g的速度就贏了',
#              '要看這一年內哪家業者可以建置越多的基地台誰就贏了',
#              '到荒郊野外你就贏了'],
#  '\\w到(快|要)?吐血\\b': ['看到吐血', '爛到快吐血', '等到吐血', '濫到吐血', '聽到快吐血'],
#  '也太\\w+了?吧?\\b': ['也太大吧', '也太划算了', '也太慘了', '也太多種', '也太多白痴了'],
#  '八成\\w+\\b': ['八成是同一電表吧', '八成是沒在關注評測影片', '八成的年輕人', '八成是內鬼', '八成被野蠻人拆基地台了'],
#  '勿忘\\w+\\b': ['勿忘499之亂', '勿忘黑心頂新', '勿忘iphone', '勿忘記亞太是以電信服務為主的公司'],
#  '只有遠傳\\s?沒有\\w{2}': ['只有遠傳 沒有速度',
#                       '只有遠傳沒有信號',
#                       '只有遠傳沒有朋友',
#                       '只有遠傳 沒有訊號',
#                       '只有遠傳沒有聲音'],
#  '坐等\\w+\\b': ['坐等降價囉', '坐等看後續有無10', '坐等今年雙11各家方案', '坐等明雙11', '坐等單辦88'],
#  '很可以\\w*': ['很可以去試看看呢', '很可以考慮一下', '很可以喔我可以不去中華辦了', '很可以啦', '很可以阿'],
#  '我也是\\w+啦': ['我也是啼笑皆非啦',
#               '我也是真的那個企業的人啦',
#               '我也是有研究過中華那個百萬好禮活動啦',
#               '我也是熊熊看到慢慢等一定會遇到的啦',
#               '我也是習慣了啦'],
#  '敲碗等\\w+\\b': ['敲碗等待中', '敲碗等中華', '敲碗等新機', '敲碗等待中了1', '敲碗等待回覆'],
#  '沒一個\\w+的': ['沒一個能打的', '沒一個肯定的', '沒一個划算的', '沒一個是真的', '沒一個是自己付電話費的啊我就真的'],
#  '直接\\w+了\\b': ['直接裝網路好了', '直接掛斷了', '直接5g就不會有煩腦了', '直接變成空號了', '直接對半砍了'],
#  '真(的|ㄉ)\\w+到有剩': ['真ㄉ爛到有剩', '真的爛到有剩', '真的是爛到有剩', '真的廢到有剩'],
#  '真的有\\w+到\\b': ['真的有便宜到', '真的有划算到', '真的有給到', '真的有辦到的人賺到', '真的有誇張到'],
#  '純噓\\w+\\b': ['純噓台灣之星爛', '純噓中華行銷叨擾長輩', '純噓樓上', '純噓台灣之星', '純噓亞太'],
#  '被\\w+到死': ['被靠北到死', '被八車的自助餐坑中午的時候排八方雲集排到死', '被扣錢扣到死', '被中華電信幹到死', '被騙到死'],
#  '誰\\w誰\\w+\\b': ['誰誰誰能值', '誰買誰傻比', '誰辦誰白癡', '誰惹誰了', '誰是誰非'],
#  '越來越\\w\\b': ['越來越久', '越來越冷', '越來越好', '越來越涼', '越來越糟']}

# %%
# export as csv file
with open('matched_random.csv', 'w') as f:
    for key in matched.keys():
        f.write("%s,%s\n"%(key, matched[key]))

# %% [markdown]
# ## 3. 將符合構式的例子及其數量整理成表格

# %%
df = pd.DataFrame([matched_con, matched]).T
df.columns = ['count', 'examples']
df = df.sort_values(by='count', ascending=False) # 數量由大到小排序
df
# Out:
#                         count                                           examples
# 直接\w+了\b                  672     [直接裝網路好了, 直接掛斷了, 直接5g就不會有煩腦了, 直接變成空號了, 直接對半砍了]
# (真的)?有夠\w+的?\b            464  [有夠正, 有夠猛的, 有夠沒誠意, 有夠差一場正常ping一場爆ping要怎麼玩, 真的有...
# 也太\w+了?吧?\b               408                  [也太大吧, 也太划算了, 也太慘了, 也太多種, 也太多白痴了]
# \b\w+根本\w{2}\b            292  [店家根本違約, 前面的人網購操作很慢根本悲劇, wifi路由器wan燈根本沒亮, 用不完的...
# 坐等\w+\b                   188    [坐等降價囉, 坐等看後續有無10, 坐等今年雙11各家方案, 坐等明雙11, 坐等單辦88]
# \b\w+到\w*炸了?              162  [幹來台南生活到哪都容易沒訊號稍微進一個建築物網路就直接炸, 真的是爛到一個炸, 慢到炸, ...
# (對\w+)?一點(都|也)不\w+\b      133    [一點都不貴, 一點都不考慮, 一點都不深奧深奧的地方在價錢, 一點都不意外, 一點都不值得]
# \b\w+屌打\w+\b              113  [那我想被原本戲謔但第二屆認真搞的走鐘獎屌打也是應該的看到其中一則留言寫得很好, 中華屌打台...
# \b\w+(的|得)要死              105    [上網恨慢得要死, 幹的要死, 我是在二樓網路真的爛的要死, 網速慢的要死, 態度還差的要死]
# \b\w+給力\b                  87  [呱張給力, 我看前面兩篇都說399給力, 88結最給力, 又覺得中華網路還是給力, iph...
# 八成\w+\b                    81  [八成是同一電表吧, 八成是沒在關注評測影片, 八成的年輕人, 八成是內鬼, 八成被野蠻人拆...
# \b\w+心酸的?\w*\b             78  [好心酸, 所以是排心酸的嗎, 但要查資料還是木抖點名的時候真的很幹我吃到飽的費用是繳心酸的...
# \b\w+被當盤子\w*\b             58  [是被當盤子耍吧, 繳4g吃到飽被當盤子, 只是被當盤子而已, 那你這四年會無數次被當盤子,...
# 越來越\w\b                    48                     [越來越久, 越來越冷, 越來越好, 越來越涼, 越來越糟]
# \b\w+是在哈囉                  46  [單是在哈囉, 自己說法前後矛盾是在哈囉, 網路是在哈囉, 這是在哈囉, 你給我更新軟體是在哈囉]
# 誰\w誰\w+\b                  44                  [誰誰誰能值, 誰買誰傻比, 誰辦誰白癡, 誰惹誰了, 誰是誰非]
# 很可以\w*                     43     [很可以去試看看呢, 很可以考慮一下, 很可以喔我可以不去中華辦了, 很可以啦, 很可以阿]
# \b\w+(掰|bye)了              39  [我想就掰了, 出了市區偏遠地區如海邊山上就掰掰了, 就要跟你說掰掰了, 所以要和便宜的吃到...
# \b\w+廢到笑                   34  [5g看到新聞報導中華初步兩千座基地台就無言了廢到笑, 企客688真的是廢到笑, 獲利王真的...
# (很|也)夠\w+了\b               34   [也夠買一隻平價機了, 也夠優了, 也夠鄉下了, 很夠了應該也不會升就是了, 也夠打94分鐘了]
# \b\w+雞肋                    30     [根本雞肋, 上傳是雞肋, 拿雞肋, 所以優惠在那個網內簡訊就是雞肋, 之前一直覺得像雞肋]
# 只有遠傳\s?沒有\w{2}             25  [只有遠傳 沒有速度, 只有遠傳沒有信號, 只有遠傳沒有朋友, 只有遠傳 沒有訊號, 只有遠...
# \b\w到爆\w?\b                24                        [卡到爆炸, 幹到爆, 香到爆, 爽到爆, 爛到爆炸]
# \b\w+(到|的|得)離譜             20  [上傳更是低得離譜, 寫的資料錯的離譜, 開台就是貴的離譜, 邏輯到離譜, 小弟住在一中商圈...
# 純噓\w+\b                    20          [純噓台灣之星爛, 純噓中華行銷叨擾長輩, 純噓樓上, 純噓台灣之星, 純噓亞太]
# \b\w+秀下限\w+\b              16  [自己搞不到管道別秀下限了, 井蛙不要秀下限好嗎, 先搞懂小七業務再來秀下限喔, 賣勾來這秀...
# 真的有\w+到\b                  15         [真的有便宜到, 真的有划算到, 真的有給到, 真的有辦到的人賺到, 真的有誇張到]
# 沒一個\w+的                    13  [沒一個能打的, 沒一個肯定的, 沒一個划算的, 沒一個是真的, 沒一個是自己付電話費的啊我...
# \w+就贏了                     13  [這樣他就贏了, 我就贏了, 最高只有35m的話4g的速度就贏了, 要看這一年內哪家業者可以...
# 敲碗等\w+\b                   11             [敲碗等待中, 敲碗等中華, 敲碗等新機, 敲碗等待中了1, 敲碗等待回覆]
# 我也是\w+啦                     9  [我也是啼笑皆非啦, 我也是真的那個企業的人啦, 我也是有研究過中華那個百萬好禮活動啦, 我...
# \b三不五時就\w+\b                9  [三不五時就卡住, 三不五時就有要你續約較高資費但可降速吃到飽的廣告, 三不五時就在發, 三...
# \w到(快|要)?吐血\b               8                   [看到吐血, 爛到快吐血, 等到吐血, 濫到吐血, 聽到快吐血]
# \b\w+敲盤子\w*\b               7  [蘋果又出來敲盤子, 不然台灣人還在被三大敲盤子, 遠傳台哥是敲盤子喔, 各家都拿高資費來敲...
# 被\w+到死                      5  [被靠北到死, 被八車的自助餐坑中午的時候排八方雲集排到死, 被扣錢扣到死, 被中華電信幹到...
# 勿忘\w+\b                     4      [勿忘499之亂, 勿忘黑心頂新, 勿忘iphone, 勿忘記亞太是以電信服務為主的公司]
# 真(的|ㄉ)\w+到有剩                4                  [真ㄉ爛到有剩, 真的爛到有剩, 真的是爛到有剩, 真的廢到有剩]
# (置|拉)板凳等\w+\b               2                                   [置板凳等後續, 拉板凳等中華]
# \b\w+能\w\s?，?\w+都能\w了\b     2                         [屁話能信史都能吃了, 店員的話能信，連屎都能吃了]

# %% [markdown]
# ## 4. 用非電信語料 (PTT 男女板) 測試構式辭典

# %%
# !gdown --id "1Aoeq6dPkgHhxJQonqPtyVPwPoRhpesPC" -O "bg.json" 
with open("bg.json", "r", encoding = "UTF-8") as f:
    bg_articles = json.load(f)['articles']

bg_content = []
for a in bg_articles:
  if 'content' in a:
    bg_content.append(a['content'])
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Aoeq6dPkgHhxJQonqPtyVPwPoRhpesPC
# To: /content/bg.json
# 27.3MB [00:00, 104MB/s]

# %%
n = 5  # sample size
random.seed(10)

bg_matched = {}
bg_matched_con = {}
for k in tq.tqdm(constructions):
  pat = re.compile(k)
  if k not in bg_matched: bg_matched[k] = []
  
  # Get all cnstr from all comments
  candidates = set()
  for cmt in bg_content:
    for c in pat.finditer(cmt): candidates.add(c[0])
  
  # Count all cnstr
  bg_matched_con[k] = len(candidates)

  # Sample
  if len(candidates) > n:
    for c in random.sample(candidates, n): bg_matched[k].append(c)
  else:
    for c in candidates: bg_matched[k].append(c)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=39.0), HTML(value='')))

# %%
bg_df = pd.DataFrame([bg_matched_con, bg_matched]).T
bg_df.columns = ['count', 'examples']
bg_df = bg_df.sort_values(by='count', ascending=False) # 數量由大到小排序
bg_df
# Out:
#                         count                                           examples
# 直接\w+了\b                   33     [直接被已讀了, 直接不演了, 直接就不見了, 直接把軟體刪了, 直接ff找下個對象就好了]
# (對\w+)?一點(都|也)不\w+\b       30  [一點也不了解你的本質, 一點也不快樂, 一點都不是, 一點都不現實, 一點都不期待不興奮也...
# (真的)?有夠\w+的?\b             30             [有夠沒種的, 真的有夠白癡, 有夠衰, 有夠可怕, 有夠廢的你為何不離開]
# 也太\w+了?吧?\b                23                  [也太神, 也太自然了吧, 也太巧合了吧, 也太多, 也太沒誠意]
# 誰\w誰\w+\b                  16  [誰誰誰對老婆女友超級好超Beta人家感情也超好的啊, 誰對誰錯還真的不好說, 誰對誰錯只從...
# \b\w+根本\w{2}\b             16  [覺得根本被玩, 你根本沒轍, 如果根本不熟, 要說誰是為了性別平等而努力根本沒有, 現在想...
# 八成\w+\b                    15  [八成以上又是對方先找我聊天的, 八成左右, 八成婚姻就已經有問題了, 八成確定這是真的理由...
# \b\w+(的|得)要死               14  [在台灣罵得要死, 畢竟社會上還是很多人幼稚得要死, 摳門小氣的要死, 還我一個禮拜我難過的...
# 越來越\w\b                    13                     [越來越忙, 越來越少, 越來越低, 越來越廢, 越來越近]
# \b\w+到\w*炸了?               10  [浪漫到炸, 煩到爆炸, 錢多到爆炸, 現在想想如果交往第14天跟她求婚他應該會傻眼到爆炸,...
# \b\w+(掰|bye)了               6  [掰掰了, AA宅就先掰了, 剩下一半大概也掰了, 需要我的時候就老公老公喊不要就一句不適合...
# \b\w+心酸的?\w*\b              5  [她們的心酸不是一般人可以承受, 而不是他講了妳心酸酸去找妳的備胎討拍, 但是這種心酸感覺是...
# \b\w+屌打\w+\b                5  [都說凱能屌打賈克斯, 你在哪裡都是被日韓屌打的啊誰叫人家國家強, 整個屌打你性格十條街, ...
# 我也是\w+啦                     4  [我也是會繼續前進啦, 我也是因為載她啊但我沒有遷怒或頻繁出現那樣啦, 我也是覺得很可笑啦,...
# 很可以\w*                      3                             [很可以之類的, 很可以接受矮, 很可以耶]
# 被\w+到死                      2                                  [被嫌到死, 被板上主流嫌棄到死]
# \w+就贏了                      2                                   [原po就贏了, 於是狼就贏了]
# \b\w+是在哈囉                   2                         [一堆人說直接登記結婚是在哈囉, 跟女生扯是在哈囉]
# \b三不五時就\w+\b                2                 [三不五時就有人上來分享, 三不五時就來這邊針對特定人士做人身攻擊]
# \b\w到爆\w?\b                 2                                        [廢到爆, 煩到爆炸]
# \b\w+敲盤子\w*\b               2                          [1S那種宰肥羊敲盤子的價格, 那是敲盤子宰肥羊]
# 坐等\w+\b                     2                              [坐等嶄新角色出現, 坐等ptt女拳智障]
# \b\w+廢到笑                    2                                [這男的廢到笑, 犯案能力根本廢到笑]
# \b\w+(到|的|得)離譜              1                           [我才發現了曾經一起以為的理想型A結論錯得離譜]
# \b\w+雞肋                     1                                          [你對她只是雞肋]
# 沒一個\w+的                     1                                      [沒一個有懶趴去碰這個的]
# (很|也)夠\w+了\b                1                                             [也夠高了]
# \b\w+給力\b                   1                                           [也就是不給力]
# \w到(快|要)?吐血\b               0                                                 []
# 純噓\w+\b                     0                                                 []
# 真(的|ㄉ)\w+到有剩                0                                                 []
# (置|拉)板凳等\w+\b               0                                                 []
# 敲碗等\w+\b                    0                                                 []
# \b\w+被當盤子\w*\b              0                                                 []
# 勿忘\w+\b                     0                                                 []
# \b\w+秀下限\w+\b               0                                                 []
# 真的有\w+到\b                   0                                                 []
# \b\w+能\w\s?，?\w+都能\w了\b     0                                                 []
# 只有遠傳\s?沒有\w{2}              0                                                 []
